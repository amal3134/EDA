# %% [markdown]
# <a href="https://colab.research.google.com/github/amal3134/EDA/blob/main/chart_and_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
#create line chart
plt.figure(figsize=(8,6))
plt.plot(x,y,marker='o',linestyle='-')
#add annoytation
for i,(xi,yi) in enumerate(zip(x,y)):
    plt.annotate(f'({xi},{yi})',xy=(xi,yi),textcoords='offset points',xytext=(0,10),ha='center')
#add title and labels
plt.title('Line Chart with annotation')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
#display grid
plt.grid(True)
#show the plot
plt.show()

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y=x*2
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Any suitable title')

plt.show()

x1=[2,4,6,8]
y1=[3,5,7,9]
plt.plot(x1,y1,'-.')

#show another chart with -. line
plt.show()

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y=x*2
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Any suitable title')

#plt.show()

x1=[2,4,6,8]
y1=[3,5,7,9]
plt.plot(x1,y1,'-.')

#show another chart with -. line
plt.show()
